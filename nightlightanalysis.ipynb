# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
import h5py
import os
for dirname, _, filenames in os.walk('/kaggle/input/dataset'):
    for filename in filenames:
        file = os.path.join(dirname, filename)
        # print(file)
        h5 = h5py.File(file, 'r')
        hdfeos = h5
        list(hdfeos.keys())

        grids = hdfeos['HDFEOS']['GRIDS']['VNP_Grid_DNB']['Data Fields']
        # for i in range(2400):
        #   for j in range(2400):
        #     if(grids[i][j]!=65535):
        #       print(grids[i][j], end=" ")
        #   print("\n")
        #print(list(grids.keys()))
        
        # for i in grids:
        #   print(i)
        # h5.close()
        for i in grids.keys():
            print(i, grids[i][100][100], grids[i][2300][2300], grids[i][2300][100], grids[i][100][2300])
        print("\n")
        h5.close()
# 
# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# BrightnessTemperature_M12 34533 36419 36667 34572
# BrightnessTemperature_M13 33413 34924 35262 32970
# BrightnessTemperature_M15 43652 44340 44279 43406
# BrightnessTemperature_M16 43366 43940 43688 43200
# DNB_At_Sensor_Radiance_500m 4 12 6 8
# Glint_Angle 14694 7662 15708 6661
# Granule 1 0 2 0
# Lunar_Azimuth -4190 -5779 -4538 -5507
# Lunar_Zenith 11985 11622 12678 11074
# Moon_Illumination_Fraction 3167 3089 3162 3094
# Moon_Phase_Angle 11151 11248 11156 11240
# QF_Cloud_Mask 114 50 50 50
# QF_DNB 0 0 0 0
# QF_VIIRS_M10 2 0 2 2
# QF_VIIRS_M11 2 2 2 2
# QF_VIIRS_M12 0 0 0 0
# QF_VIIRS_M13 0 0 0 0
# QF_VIIRS_M15 0 0 0 0
# QF_VIIRS_M16 0 0 0 0
# Radiance_M10 28 48 28 21
# Radiance_M11 34 29 34 30
# Sensor_Azimuth -7447 9662 -7504 9556
# Sensor_Zenith 3659 4330 5136 5030
# Solar_Azimuth 3357 2120 3631 1882
# Solar_Zenith 10917 12309 11641 11465
# UTC_Time 9.001546 7.3631043 9.042599 7.320383
#
#
# BrightnessTemperature_M12 31866 36035 36306 33992
# ...
